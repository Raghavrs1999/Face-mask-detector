# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install ultralytics
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 599.6/599.6 kB 10.7 MB/s eta 0:00:00
# ...

# %%
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.118 🚀 Python-3.10.12 torch-2.0.1+cu118 CPU
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 24.1/107.7 GB disk)

# %%
# %ls
# Out:
# drive/

# %%
# %cd drive/MyDrive/mask_detection/
# Out:
# /content/drive/MyDrive/mask_detection

# %%
EPOCHS = 100
MODE = 'train'
DATA = '/content/drive/MyDrive/mask_detection/data.yaml'



# !yolo task=detect mode={MODE} model=yolov8m.pt imgsz=512 data={DATA} epochs={EPOCHS} batch=8 name=mask
# Out:
# Ultralytics YOLOv8.0.118 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !yolo task=detect \
mode=predict \
model=/content/drive/MyDrive/mask_detection/runs/detect/mask2/weights/best.pt \
source=/content/drive/MyDrive/mask_detection/dataset_mask/val/imgaes \
imgsz=512 \
name=make \
hide_labels=False
# Out:
# WARNING ⚠️ 'hide_labels' is deprecated and will be removed in 'ultralytics 8.2' in the future. Please use 'show_labels' instead.
# Ultralytics YOLOv8.0.118 🚀 Python-3.10.12 torch-2.0.1+cu118 CPU
# Model summary (fused): 218 layers, 25841497 parameters, 0 gradients
#
# image 1/748 /content/drive/MyDrive/mask_detection/dataset_mask/val/imgaes/maksssksksss0.png: 384x512 2 without_masks, 1 with_mask, 611.3ms
# image 2/748 /content/drive/MyDrive/mask_detection/dataset_mask/val/imgaes/maksssksksss1.png: 224x512 1 without_mask, 8 with_masks, 288.4ms
# image 3/748 /content/drive/MyDrive/mask_detection/dataset_mask/val/imgaes/maksssksksss10.png: 512x416 1 with_mask, 538.1ms
# image 4/748 /content/drive/MyDrive/mask_detection/dataset_mask/val/imgaes/maksssksksss100.png: 320x512 3 with_masks, 419.4ms
# image 5/748 /content/drive/MyDrive/mask_detection/dataset_mask/val/imgaes/maksssksksss101.png: 512x416 1 with_mask, 536.8ms
# ...

# %%
from ultralytics import YOLO

# Load a model
model = YOLO('yolov8m.pt')  # load an official model
model = YOLO('/content/drive/MyDrive/mask_detection/runs/detect/mask2/weights/best.pt')  # load a custom model

# Predict with the model
results = model('/content/drive/MyDrive/mask_detection/dataset_mask/train/imgaes/maksssksksss11.png')  # predict on an image
# Out:
# image 1/1 /content/drive/MyDrive/mask_detection/dataset_mask/train/imgaes/maksssksksss11.png: 352x512 22 with_masks, 1 mask_weared_incorrect, 596.6ms
# Speed: 13.9ms preprocess, 596.6ms inference, 27.8ms postprocess per image at shape (1, 3, 512, 512)
